# %%
from netCDF4 import Dataset
import netCDF4
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import numpy as np
from datetime import datetime, timezone
import nc_time_axis
import xarray as xr
import math

atmos_epoch = datetime(1900, 1, 1, 0, 0, tzinfo=timezone.utc)

# %%
ukesm_slp = Dataset('../data/ukesm/psl_day_UKESM1-0-LL_piControl_r1i1p1f2_gn_19600101-20601230_NHML_JJAextd_1x1.nc', mode='r')
ukesm_geopotential = Dataset('../data/ukesm/500zg_day_UKESM1-0-LL_piControl_r1i1p1f2_gn_19600101-20601230_NHML_JJAextd.nc_1x1.nc', mode='r')
ukesm_labels = Dataset('../data/original/labels/GTD_UKESM1-0-LL_piControl_1960-2060_JJAextd.nc', mode='r')

### load data
geopotential_xarray = xr.open_dataset(xr.backends.NetCDF4DataStore(ukesm_geopotential), decode_times=True)
slp_xarray = xr.open_dataset(xr.backends.NetCDF4DataStore(ukesm_slp), decode_times=True)
labels_xarray = xr.open_dataset(xr.backends.NetCDF4DataStore(ukesm_labels), decode_times=True)
long = np.arange(-45, 55, 1)
lat = np.arange(30, 75, 1)

# %%
fig, axs = plt.subplots(nrows=1,ncols=5,
                        subplot_kw={'projection': ccrs.PlateCarree()},
                        figsize=(20, 20))

axs = axs.flatten()


for i in range(5):
    axs[i].coastlines(resolution="110m",linewidth=1)
    cs = axs[i].contourf(long, lat, geopotential_xarray.zg[i], transform=ccrs.PlateCarree(),cmap=plt.cm.jet)

# %%
### a simplistic method to subtract the daily average values
def deseasonalization(ds):
    daily_climatology = ds.groupby('time.dayofyear').mean(dim='time')
    window_size=10
    ### make sure the circular nature of the data is recognized when taking the rolling mean
    daily_climatology_circular = xr.concat([daily_climatology.isel(dayofyear=slice(-window_size//2, None)),
                        daily_climatology,
                        daily_climatology.isel(dayofyear=slice(None, window_size//2))],
                        dim='dayofyear')
    # smooth the daily data for the climatology, because it is noisy
    daily_climatology_circular = daily_climatology_circular.rolling(dayofyear=10,center=True,min_periods=1).mean()
    daily_climatology = daily_climatology_circular.isel(dayofyear=slice(window_size//2,-window_size//2))
    # Subtract the daily climatology from the original data to get deseasonalized data
    ds_deseasonalized = ds - daily_climatology.sel(dayofyear=ds.time.dt.dayofyear)
    return ds_deseasonalized
    
### deaseasonalize and then divide by the respective standard deviation
ds_obs_anom = deseasonalization(geopotential_xarray)
ds_obs_anom.zg.data = ds_obs_anom.zg.data/np.std(ds_obs_anom.zg.data,axis=0)

# %%
# linear de-trending of co2 effect on geoptotential height

# def detrending(ds):
#     x = np.arange(len(ds.time))
#     coef = np.polyfit(x, ds.mean(), 1)
#     poly1d_fn = np.poly1d(coef)
#     return ds - poly1d_fn(x)

# ds_obs_anom_detrended = detrending(ds_obs_anom)

def detrending(ds):
    x = np.arange(len(ds.time))
    mean = np.mean(ds.zg.to_numpy(), axis=(1,2))
    coef = np.polyfit(x, mean, 1)
    poly1d_fn = np.poly1d(coef)
    
    poly_array = np.array([np.full((len(ds_obs_anom.zg[0]), len(ds_obs_anom.zg[0, 0])), poly1d_fn(x)) for x in range(len(ds.time))])
    detrended_ds = ds - poly_array
    return detrended_ds

# Assuming ds_obs_anom is an xarray dataset with a 'time' dimension
ds_obs_anom = detrending(ds_obs_anom)

# %%
# plot observational data onto worldmap

fig = plt.figure(figsize=(6, 6))
ax = plt.axes(projection=ccrs.PlateCarree())
# ax.set_extent([-180, 180, 20, 90], crs=ccrs.PlateCarree())
ax.coastlines(resolution="110m",linewidth=1)
ax.gridlines(linestyle='--',color='black')

plt.contourf(long, lat, ds_obs_anom.zg[0], transform=ccrs.PlateCarree(),cmap=plt.cm.jet)
plt.title('Observational Blocking Data', size=14)
cb = plt.colorbar(ax=ax, orientation="horizontal", pad=0.02, aspect=16, shrink=0.8)
cb.ax.tick_params(labelsize=10)

# %%
import os

try:
    os.remove('../data/ukesm/500zg_day_UKESM1-0-LL_piControl_r1i1p1f2_gn_19600101-20601230_NHML_JJAextd.nc_1x1_final.nc')
except:
    pass

ncfile = Dataset('../data/ukesm/500zg_day_UKESM1-0-LL_piControl_r1i1p1f2_gn_19600101-20601230_NHML_JJAextd.nc_1x1_final.nc', mode='w', format='NETCDF4')

ncfile.set_fill_off()

ncfile.createDimension("time", None)
ncfile.createDimension("longitude", 100)
ncfile.createDimension("latitude", 45)
ncfile.createDimension("day_range", 5)

variable = ncfile.createVariable("time", "i4", ("time",))
variable.setncatts({k: ukesm_geopotential.variables["time"].getncattr(k) for k in ukesm_geopotential.variables["time"].ncattrs()})
ncfile.createVariable("day_range", "i4", ("day_range",))
variable = ncfile.createVariable("longitude", "f4", ("longitude",))
variable.setncatts({k: ukesm_geopotential.variables["lon"].getncattr(k) for k in ukesm_geopotential.variables["lon"].ncattrs()})
variable = ncfile.createVariable("latitude", "f4", ("latitude",))
variable.setncatts({k: ukesm_geopotential.variables["lat"].getncattr(k) for k in ukesm_geopotential.variables["lat"].ncattrs()})
variable = ncfile.createVariable("z_0001", "f4", ("time", "day_range", "latitude", "longitude"))
# variable.setncatts({k: ukesm_geopotential.variables["z_0001"].getncattr(k) for k in ukesm_geopotential.variables["z_0001"].ncattrs()})

len_time = ds_obs_anom.time.shape[0]
len_lat = ds_obs_anom.lat.shape[0]
len_long = ds_obs_anom.lon.shape[0]

result = np.zeros((len_time, 5, len_lat, len_long))

temp_zg = ds_obs_anom.zg.data
for i in range(len_time):
    if (i % 50 == 0): print("working on " + str(i) + " of " + str(len_time))
    if len(temp_zg) < 5:
        ncfile.variables["z_0001"][i] = np.array([temp_zg[0], temp_zg[0], temp_zg[0], temp_zg[0], temp_zg[0]])
    else:
        ncfile.variables["z_0001"][i] = np.array([temp_zg[0], temp_zg[0 + 1], temp_zg[0 + 2], temp_zg[0 + 3], temp_zg[0 + 4]])
    temp_zg = temp_zg[1:]
print(result.shape)

# decode times back to hours since 1900-01-01 00:00:00

ncfile.variables["time"][:] = ukesm_geopotential.variables["time"][:]
ncfile.variables["longitude"][:] = ds_obs_anom.lon.data[:]
ncfile.variables["latitude"][:] = ds_obs_anom.lat.data[:]
ncfile.variables["day_range"][:] = [0, 1, 2, 3, 4]

ncfile.close()
# Out:
# working on 0 of 9898
# working on 50 of 9898
# working on 100 of 9898
# working on 150 of 9898
# working on 200 of 9898
# working on 250 of 9898
# working on 300 of 9898
# working on 350 of 9898
# working on 400 of 9898
# working on 450 of 9898
# working on 500 of 9898
# working on 550 of 9898
# working on 600 of 9898
# working on 650 of 9898
# working on 700 of 9898
# working on 750 of 9898
# working on 800 of 9898
# working on 850 of 9898
# working on 900 of 9898
# working on 950 of 9898
# working on 1000 of 9898
# working on 1050 of 9898
# working on 1100 of 9898
# working on 1150 of 9898
# working on 1200 of 9898
# working on 1250 of 9898
# working on 1300 of 9898
# working on 1350 of 9898
# working on 1400 of 9898
# working on 1450 of 9898
# working on 1500 of 9898
# working on 1550 of 9898
# working on 1600 of 9898
# working on 1650 of 9898
# working on 1700 of 9898
# working on 1750 of 9898
# working on 1800 of 9898
# working on 1850 of 9898
# working on 1900 of 9898
# working on 1950 of 9898
# working on 2000 of 9898
# working on 2050 of 9898
# working on 2100 of 9898
# working on 2150 of 9898
# working on 2200 of 9898
# working on 2250 of 9898
# working on 2300 of 9898
# working on 2350 of 9898
# working on 2400 of 9898
# working on 2450 of 9898
# working on 2500 of 9898
# working on 2550 of 9898
# working on 2600 of 9898
# working on 2650 of 9898
# working on 2700 of 9898
# working on 2750 of 9898
# working on 2800 of 9898
# working on 2850 of 9898
# working on 2900 of 9898
# working on 2950 of 9898
# working on 3000 of 9898
# working on 3050 of 9898
# working on 3100 of 9898
# working on 3150 of 9898
# working on 3200 of 9898
# working on 3250 of 9898
# working on 3300 of 9898
# working on 3350 of 9898
# working on 3400 of 9898
# working on 3450 of 9898
# working on 3500 of 9898
# working on 3550 of 9898
# working on 3600 of 9898
# working on 3650 of 9898
# working on 3700 of 9898
# working on 3750 of 9898
# working on 3800 of 9898
# working on 3850 of 9898
# working on 3900 of 9898
# working on 3950 of 9898
# working on 4000 of 9898
# working on 4050 of 9898
# working on 4100 of 9898
# working on 4150 of 9898
# working on 4200 of 9898
# working on 4250 of 9898
# working on 4300 of 9898
# working on 4350 of 9898
# working on 4400 of 9898
# working on 4450 of 9898
# working on 4500 of 9898
# working on 4550 of 9898
# working on 4600 of 9898
# working on 4650 of 9898
# working on 4700 of 9898
# working on 4750 of 9898
# working on 4800 of 9898
# working on 4850 of 9898
# working on 4900 of 9898
# working on 4950 of 9898
# working on 5000 of 9898
# working on 5050 of 9898
# working on 5100 of 9898
# working on 5150 of 9898
# working on 5200 of 9898
# working on 5250 of 9898
# working on 5300 of 9898
# working on 5350 of 9898
# working on 5400 of 9898
# working on 5450 of 9898
# working on 5500 of 9898
# working on 5550 of 9898
# working on 5600 of 9898
# working on 5650 of 9898
# working on 5700 of 9898
# working on 5750 of 9898
# working on 5800 of 9898
# working on 5850 of 9898
# working on 5900 of 9898
# working on 5950 of 9898
# working on 6000 of 9898
# working on 6050 of 9898
# working on 6100 of 9898
# working on 6150 of 9898
# working on 6200 of 9898
# working on 6250 of 9898
# working on 6300 of 9898
# working on 6350 of 9898
# working on 6400 of 9898
# working on 6450 of 9898
# working on 6500 of 9898
# working on 6550 of 9898
# working on 6600 of 9898
# working on 6650 of 9898
# working on 6700 of 9898
# working on 6750 of 9898
# working on 6800 of 9898
# working on 6850 of 9898
# working on 6900 of 9898
# working on 6950 of 9898
# working on 7000 of 9898
# working on 7050 of 9898
# working on 7100 of 9898
# working on 7150 of 9898
# working on 7200 of 9898
# working on 7250 of 9898
# working on 7300 of 9898
# working on 7350 of 9898
# working on 7400 of 9898
# working on 7450 of 9898
# working on 7500 of 9898
# working on 7550 of 9898
# working on 7600 of 9898
# working on 7650 of 9898
# working on 7700 of 9898
# working on 7750 of 9898
# working on 7800 of 9898
# working on 7850 of 9898
# working on 7900 of 9898
# working on 7950 of 9898
# working on 8000 of 9898
# working on 8050 of 9898
# working on 8100 of 9898
# working on 8150 of 9898
# working on 8200 of 9898
# working on 8250 of 9898
# working on 8300 of 9898
# working on 8350 of 9898
# working on 8400 of 9898
# working on 8450 of 9898
# working on 8500 of 9898
# working on 8550 of 9898
# working on 8600 of 9898
# working on 8650 of 9898
# working on 8700 of 9898
# working on 8750 of 9898
# working on 8800 of 9898
# working on 8850 of 9898
# working on 8900 of 9898
# working on 8950 of 9898
# working on 9000 of 9898
# working on 9050 of 9898
# working on 9100 of 9898
# working on 9150 of 9898
# working on 9200 of 9898
# working on 9250 of 9898
# working on 9300 of 9898
# working on 9350 of 9898
# working on 9400 of 9898
# working on 9450 of 9898
# working on 9500 of 9898
# working on 9550 of 9898
# working on 9600 of 9898
# working on 9650 of 9898
# working on 9700 of 9898
# working on 9750 of 9898
# working on 9800 of 9898
# working on 9850 of 9898
# (9898, 5, 45, 100)

# %%
data = Dataset('../data/geopotential_height_500hPa_era5_6hourly_z0001_daymean_final.nc', mode='r')

plt.subplot(2, 1, 2)
plt.ylabel("de-seasonalized data")
time = netCDF4.num2date(data.variables["time"][:], data.variables["time"].units, data.variables["time"].calendar)
plt.plot(time[::10], np.mean(data.variables["z_0001"][::10], axis=(1, 2)))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 5
#       3 plt.subplot(2, 1, 2)
#       4 plt.ylabel("de-seasonalized data")
# ----> 5 time = netCDF4.num2date(data.variables["time"][:], data.variables["time"].units, data.variables["time"].calendar)
#       6 plt.plot(time[::10], np.mean(data.variables["z_0001"][::10], axis=(1, 2)))
#       7 plt.show()
#
# File src/netCDF4/_netCDF4.pyx:4923, in netCDF4._netCDF4.Variable.__getattr__()
#
# File src/netCDF4/_netCDF4.pyx:4645, in netCDF4._netCDF4.Variable.getncattr()
#
# File src/netCDF4/_netCDF4.pyx:1544, in netCDF4._netCDF4._get_att()
#
# File src/netCDF4/_netCDF4.pyx:2034, in netCDF4._netCDF4._ensure_nc_success()
#
# AttributeError: NetCDF: Attribute not found
