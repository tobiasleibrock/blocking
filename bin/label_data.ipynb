# %%
from netCDF4 import Dataset
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import numpy as np
import netCDF4

# %%
# 4264x
observational_labels = Dataset('../data/labels/GTD_1979-2019_JJAextd.nc', mode='r')
ukesm_labels = Dataset('../data/labels/GTD_UKESM1-0-LL_piControl_1960-2060_JJAextd.nc', mode='r')

# %%
obs_time = observational_labels.variables["time"]
obs_time_convert = netCDF4.num2date(obs_time[:], obs_time.units, obs_time.calendar)
obs_labels = observational_labels.variables["blocking"]

for i in range(2000):
    print("time: " + str(obs_time_convert[len(obs_time_convert) - i - 1]))
    # print("blocking: " + str(obs_labels[len(obs_time_convert) - i - 1]))
    # print()
# Out:
# time: 2019-09-06 10:30:00
# time: 2019-09-05 10:30:00
# time: 2019-09-04 10:30:00
# time: 2019-09-03 10:30:00
# time: 2019-09-02 10:30:00
# time: 2019-09-01 10:30:00
# time: 2019-08-31 10:30:00
# time: 2019-08-30 10:30:00
# time: 2019-08-29 10:30:00
# time: 2019-08-28 10:30:00
# time: 2019-08-27 10:30:00
# time: 2019-08-26 10:30:00
# time: 2019-08-25 10:30:00
# time: 2019-08-24 10:30:00
# time: 2019-08-23 10:30:00
# time: 2019-08-22 10:30:00
# time: 2019-08-21 10:30:00
# time: 2019-08-20 10:30:00
# time: 2019-08-19 10:30:00
# time: 2019-08-18 10:30:00
# time: 2019-08-17 10:30:00
# time: 2019-08-16 10:30:00
# time: 2019-08-15 10:30:00
# time: 2019-08-14 10:30:00
# time: 2019-08-13 10:30:00
# time: 2019-08-12 10:30:00
# time: 2019-08-11 10:30:00
# time: 2019-08-10 10:30:00
# time: 2019-08-09 10:30:00
# time: 2019-08-08 10:30:00
# time: 2019-08-07 10:30:00
# time: 2019-08-06 10:30:00
# time: 2019-08-05 10:30:00
# time: 2019-08-04 10:30:00
# time: 2019-08-03 10:30:00
# ...
